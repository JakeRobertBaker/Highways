# %% [markdown]
# ## Imports

# %%
import urllib.request, json
import pandas as pd
import geopandas
import folium
import matplotlib.pyplot as plt
import pickle
import math
import datetime
import collections
from tqdm import tqdm

# %% [markdown]
# ### Import Query results
#
# These are the resuts of two queries.
# 1. A simple query of all site information
# 2. The quality of each site in our range

# %%
with open('sites.pickle', 'rb') as f:
    sites = pickle.load(f)
    
with open('quality_responces.pickle', 'rb') as f:
    quality_responces = pickle.load(f)
    
# Put these into a dataframe
# Specify the area we are looking at
max_lat = 52.50
max_long = -1.67
min_lat = 52.42
min_long = -1.75

sites_df = pd.DataFrame(data = sites)
area_sites_df = sites_df.loc[(min_long < sites_df.Longitude) & (sites_df.Longitude < max_long)
                            & (min_lat < sites_df.Latitude) & (sites_df.Latitude < max_lat)]


quality_responces_df  = pd.DataFrame(data = quality_responces)
good_quality_responces_df = quality_responces_df.loc[quality_responces_df.data_quality >= 40]

# Filter our sites dataframe onto this set of sites
good_quality_sites = area_sites_df.loc[area_sites_df.Id.isin(good_quality_responces_df.sites) ]

good_quality_sites = good_quality_sites.reset_index(drop=True)
good_quality_sites
# Out:
#        Id                                               Name Description  \
# 0     175  MIDAS site at M42/6482L priority 1 on link 126...   M42/6482L
# 1     561  MIDAS site at M42/6473B priority 1 on link 199...   M42/6473B
# 2    1102  MIDAS site at M42/6468A priority 1 on link 126...   M42/6468A
# 3    1608  MIDAS site at M6/5711L priority 1 on link 1110...    M6/5711L
# 4    1747  MIDAS site at M6/5732B priority 1 on link 1990...    M6/5732B
# 5    1926  MIDAS site at M42/6472A priority 1 on link 126...   M42/6472A
# 6    2017  MIDAS site at M6/5730A priority 1 on link 1990...    M6/5730A
# 7    2253  MIDAS site at M600/1134A priority 1 on link 12...  M600/1134A
# 8    2330  MIDAS site at M6/5722A priority 1 on link 1990...    M6/5722A
# 9    2951  MIDAS site at M42/6467K priority 1 on link 199...   M42/6467K
# 10   3103  MIDAS site at M42/6482B priority 1 on link 126...   M42/6482B
# 11   4403  MIDAS site at M42/6461A priority 1 on link 199...   M42/6461A
# 12   4458  MIDAS site at M6/5737A priority 1 on link 1990...    M6/5737A
# 13   4604  MIDAS site at M42/6421J priority 1 on link 199...   M42/6421J
# 14   5297  MIDAS site at M6/5733A priority 1 on link 1990...    M6/5733A
# 15   9092  TMU Site 7642/1 on A452 northbound between A45...      7642/1
# 16   9093  TMU Site 7642/2 on A452 southbound between A44...      7642/2
# 17   9490  TMU Site 7132/1 on A45 eastbound between M42 a...      7132/1
# 18   9491  TMU Site 7133/1 on A45 westbound between A452 ...      7133/1
# 19  10337  MIDAS site at M42/6450M priority 1 on link 112...   M42/6450M
# 20  10341  MIDAS site at M42/6401B priority 1 on link 112...   M42/6401B
# 21  10373  MIDAS site at M6/5717L priority 1 on link 1110...    M6/5717L
# 22  10398  MIDAS site at M42/6438A priority 1 on link 199...   M42/6438A
# 23  10430  MIDAS site at M42/6457B priority 1 on link 199...   M42/6457B
# 24  10445  MIDAS site at M42/6428K priority 1 on link 112...   M42/6428K
# 25  10560  MIDAS site at M42/6450B priority 1 on link 112...   M42/6450B
# 26  10701  MIDAS site at M42/6428B priority 1 on link 112...   M42/6428B
# 27  10705  MIDAS site at M42/6456J priority 1 on link 199...   M42/6456J
# 28  10706  MIDAS site at M42/6457A priority 1 on link 199...   M42/6457A
# 29  10712  MIDAS site at M42/6420M1 priority 1 on link 11...  M42/6420M1
# 30  10715  MIDAS site at M42/6430L priority 1 on link 200...   M42/6430L
# 31  10722  MIDAS site at M42/6420B priority 1 on link 112...   M42/6420B
# 32  10728  MIDAS site at M42/6429A priority 1 on link 199...   M42/6429A
# 33  10745  MIDAS site at M42/6457J priority 1 on link 199...   M42/6457J
# 34  10766  MIDAS site at M42/6456M1 priority 1 on link 19...  M42/6456M1
# 35  10771  MIDAS site at M42/6456M2 priority 1 on link 19...  M42/6456M2
# 36  10790  MIDAS site at M42/6420M2 priority 1 on link 11...  M42/6420M2
# 37  18190  MIDAS site at M6/5682B priority 1 on link 1261...    M6/5682B
# 38  18195  MIDAS site at M6/5697J priority 1 on link 1110...    M6/5697J
# 39  18198  MIDAS site at M6/5697A priority 1 on link 1990...    M6/5697A
# 40  18199  MIDAS site at M600/1091B priority 1 on link 12...  M600/1091B
# 41  18208  MIDAS site at M6/5701M priority 1 on link 1110...    M6/5701M
# 42  18209  MIDAS site at M6/5701A priority 1 on link 1990...    M6/5701A
# 43  18211  MIDAS site at M6/5707K priority 1 on link 1990...    M6/5707K
# 44  18212  MIDAS site at M6/5690A priority 1 on link 1110...    M6/5690A
# 45  18217  MIDAS site at M6/5692A priority 1 on link 1110...    M6/5692A
# 46  18224  MIDAS site at M600/1094B priority 1 on link 12...  M600/1094B
# 47  18227  MIDAS site at M6/5686B priority 1 on link 1261...    M6/5686B
# 48  18230  MIDAS site at M6/5701B priority 1 on link 1110...    M6/5701B
#
#     Longitude   Latitude  Status
# 0   -1.716752  52.497242  Active
# 1   -1.713067  52.490841  Active
# 2   -1.711725  52.484392  Active
# 3   -1.715598  52.479798  Active
# 4   -1.734829  52.494379  Active
# 5   -1.714189  52.488263  Active
# 6   -1.733881  52.492723  Active
# 7   -1.716796  52.494985  Active
# 8   -1.727512  52.486631  Active
# 9   -1.714836  52.483833  Active
# 10  -1.717500  52.497756  Active
# 11  -1.710646  52.478204  Active
# 12  -1.737882  52.498540  Active
# 13  -1.712179  52.441887  Active
# 14  -1.735663  52.495199  Active
# 15  -1.691470  52.449594  Active
# 16  -1.691249  52.449683  Active
# 17  -1.701929  52.445674  Active
# 18  -1.696631  52.445795  Active
# 19  -1.710256  52.468125  Active
# 20  -1.719316  52.425237  Active
# 21  -1.722982  52.483376  Active
# 22  -1.710605  52.457571  Active
# 23  -1.711185  52.474672  Active
# 24  -1.709163  52.448686  Active
# 25  -1.710299  52.468323  Active
# 26  -1.708754  52.448172  Active
# 27  -1.711707  52.473666  Active
# 28  -1.711465  52.474592  Active
# 29  -1.710627  52.442935  Active
# 30  -1.708439  52.449007  Active
# 31  -1.710921  52.442981  Active
# 32  -1.708980  52.449566  Active
# 33  -1.711834  52.474467  Active
# 34  -1.711000  52.473719  Active
# 35  -1.711060  52.473530  Active
# 36  -1.710791  52.442738  Active
# 37  -1.675357  52.475820  Active
# 38  -1.696891  52.476524  Active
# 39  -1.696935  52.476552  Active
# 40  -1.672908  52.474393  Active
# 41  -1.702529  52.476700  Active
# 42  -1.702988  52.476360  Active
# 43  -1.711550  52.477397  Active
# 44  -1.686682  52.477379  Active
# 45  -1.689627  52.477387  Active
# 46  -1.676622  52.475887  Active
# 47  -1.680658  52.477642  Active
# 48  -1.702575  52.476503  Active

# %% [markdown]
# ### Get the Reports

# %%
def daily_report_query_url(site_id, page_num, start_date = '15062021', end_date = '15062022'):
    query_url = f"https://webtris.highwaysengland.co.uk/api/v1/reports/Daily?sites={site_id}&start_date={start_date}&end_date={end_date}&page={page_num}&page_size=10000"
    return query_url


def get_site_report(site_id, start_date='15062021', end_date='15062022'):
    
    # Download page 1
    report_url = daily_report_query_url(site_id, 1, start_date, end_date)
    with urllib.request.urlopen(report_url) as url:
        report_page = json.loads(url.read().decode())
        
    
    # Work out how many pages are required    
    header = report_page['Header']
    rows = report_page['Rows']
    row_count = header['row_count']
    total_pages = math.ceil(row_count / 10000)
    
    # Make a dataframe of the rows so dar
    report_df = pd.DataFrame(data = rows)
    
    for i in range(2, total_pages+1):
        # Get page i of the report
        report_url = daily_report_query_url(site_id, i, start_date, end_date)
        with urllib.request.urlopen(report_url) as url:
            report_page = json.loads(url.read().decode())
        
        rows = report_page['Rows']
        current_page_df = pd.DataFrame(data = rows)
        report_df = pd.concat([report_df, current_page_df], ignore_index=True)

    return report_df, header

# %%
reports = collections.defaultdict(str)

for site_id in tqdm(good_quality_sites.Id):
    report, header = get_site_report(site_id, start_date='01062021', end_date = '15062022')
    report['site_id'] = site_id
    reports[site_id] = report
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 49/49 [03:27<00:00,  4.23s/it]

# %%
# Combine reports into one df
report_df = pd.concat(list(reports.values()), ignore_index=True)
# Save this df
report_df.to_feather('all_reports.feather')

# %% [markdown]
# ### Data Cleaning

# %%
# Import df
report_df = pd.read_feather('all_reports.feather')

# %%
clean_col_names = ['site_name',
     'report_date',
     'time_period_ending',
     'time_interval',
     '0-520cm',
     '521-660cm',
     '661-1160cm',
     '1160+cm',
     '0-10mph',
     '11-15mph',
     '16-20mph',
     '21-25mph',
     '26-30mph',
     '31-35mph',
     '36-40mph',
     '41-45mph',
     '46-50mph',
     '51-55mph',
     '56-60mph',
     '61-70mph',
     '71-80mph',
     '80+mph',
     'avg_mph',
     'total_volume',
     'site_id']

# %%
report_df.columns = clean_col_names
report_df
# Out:
#          site_name          report_date time_period_ending time_interval  \
# 0        M42/6482L  2021-06-01T00:00:00           00:14:00             0
# 1        M42/6482L  2021-06-01T00:00:00           00:29:00             1
# 2        M42/6482L  2021-06-01T00:00:00           00:44:00             2
# 3        M42/6482L  2021-06-01T00:00:00           00:59:00             3
# 4        M42/6482L  2021-06-01T00:00:00           01:14:00             4
# ...            ...                  ...                ...           ...
# 1783195   M6/5701B  2022-06-15T00:00:00           22:59:59            91
# 1783196   M6/5701B  2022-06-15T00:00:00           23:14:59            92
# 1783197   M6/5701B  2022-06-15T00:00:00           23:29:59            93
# 1783198   M6/5701B  2022-06-15T00:00:00           23:44:59            94
# 1783199   M6/5701B  2022-06-15T00:00:00           23:59:59            95
#
#         0-520cm 521-660cm 661-1160cm 1160+cm 0-10mph 11-15mph  ... 41-45mph  \
# 0            39         4          3       7                   ...
# 1            37         8          2       9                   ...
# 2            21         9          1       2                   ...
# 3            25         4          2       6                   ...
# 4            23         8          3       4                   ...
# ...         ...       ...        ...     ...     ...      ...  ...      ...
# 1783195                                                        ...
# 1783196                                                        ...
# 1783197                                                        ...
# 1783198                                                        ...
# 1783199                                                        ...
#
#         46-50mph 51-55mph 56-60mph 61-70mph 71-80mph 80+mph avg_mph  \
# 0                                                                61
# 1                                                                65
# 2                                                                69
# 3                                                                66
# 4                                                                66
# ...          ...      ...      ...      ...      ...    ...     ...
# 1783195
# 1783196
# 1783197
# 1783198
# 1783199
#
#         total_volume site_id
# 0                 53     175
# 1                 56     175
# 2                 33     175
# 3                 37     175
# 4                 38     175
# ...              ...     ...
# 1783195                18230
# 1783196                18230
# 1783197                18230
# 1783198                18230
# 1783199                18230
#
# [1783200 rows x 25 columns]

# %%
tidy_report = report_df[[
     'site_name',
     'site_id',
     'report_date',
     'time_period_ending',
     'time_interval',
     '0-520cm',
     '521-660cm',
     '661-1160cm',
     '1160+cm',
     'avg_mph',
     'total_volume']]
tidy_report
# Out:
#          site_name site_id          report_date time_period_ending  \
# 0        M42/6482L     175  2021-06-01T00:00:00           00:14:00
# 1        M42/6482L     175  2021-06-01T00:00:00           00:29:00
# 2        M42/6482L     175  2021-06-01T00:00:00           00:44:00
# 3        M42/6482L     175  2021-06-01T00:00:00           00:59:00
# 4        M42/6482L     175  2021-06-01T00:00:00           01:14:00
# ...            ...     ...                  ...                ...
# 1783195   M6/5701B   18230  2022-06-15T00:00:00           22:59:59
# 1783196   M6/5701B   18230  2022-06-15T00:00:00           23:14:59
# 1783197   M6/5701B   18230  2022-06-15T00:00:00           23:29:59
# 1783198   M6/5701B   18230  2022-06-15T00:00:00           23:44:59
# 1783199   M6/5701B   18230  2022-06-15T00:00:00           23:59:59
#
#         time_interval 0-520cm 521-660cm 661-1160cm 1160+cm avg_mph  \
# 0                   0      39         4          3       7      61
# 1                   1      37         8          2       9      65
# 2                   2      21         9          1       2      69
# 3                   3      25         4          2       6      66
# 4                   4      23         8          3       4      66
# ...               ...     ...       ...        ...     ...     ...
# 1783195            91
# 1783196            92
# 1783197            93
# 1783198            94
# 1783199            95
#
#         total_volume
# 0                 53
# 1                 56
# 2                 33
# 3                 37
# 4                 38
# ...              ...
# 1783195
# 1783196
# 1783197
# 1783198
# 1783199
#
# [1783200 rows x 11 columns]

# %%
interger_cols = [
     '0-520cm',
     '521-660cm',
     '661-1160cm',
     '1160+cm',
     'total_volume']

# %%
tidy_report = tidy_report.loc[tidy_report['total_volume'] != '']
tidy_report.loc[:,interger_cols] = tidy_report[interger_cols].astype('int32')
# Out:
# /tmp/ipykernel_2585139/3780097625.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tidy_report.loc[:,interger_cols] = tidy_report[interger_cols].astype('int32')

# %%
def get_timestamp(row):
    year, month,day = row['report_date'].split('T')[0].split('-')
    hour, minute, second = row['time_period_ending'].split(':')
    
    return datetime.datetime(int(year),int(month),int(day), int(hour), int(minute))

# %%
tidy_report.loc[:,'timestamp'] = tidy_report.apply(get_timestamp,axis=1)
tidy_report.loc[:,'hour'] = tidy_report.timestamp.dt.hour.astype(str)
tidy_report.loc[:,'DOW'] =  tidy_report.timestamp.dt.day_of_week.astype(str)
tidy_report.loc[:,'month'] = tidy_report.timestamp.dt.month.astype(str)
# Out:
# /tmp/ipykernel_2585139/2588312128.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tidy_report.loc[:,'timestamp'] = tidy_report.apply(get_timestamp,axis=1)
# /tmp/ipykernel_2585139/2588312128.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tidy_report.loc[:,'hour'] = tidy_report.timestamp.dt.hour.astype(str)
# /tmp/ipykernel_2585139/2588312128.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tidy_report.loc[:,'DOW'] =  tidy_report.timestamp.dt.day_of_week.astype(str)
# /tmp/ipykernel_2585139/2588312128.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tidy_report.loc[:,'month'] = tidy_report.timestamp.dt.month.astype(str)

# %% [markdown]
# ### Get Normalised counts

# %%
# Normalise by dividing each count by it's mean

# tidy_report.loc[:,'normal'] = tidy_report.groupby('site_id').total_volume.apply( lambda x: x/x.mean() )
# tidy_report[interger_cols].groupby('site_id').transform("mean")
# mean = tidy_report.groupby('site_id')['total_volume'].transform("mean")
# tidy_report.loc[:,'normal'] = tidy_report['total_volume'] / mean

for name in interger_cols:
    print(name)
    new_name = f"{name}_normalised"
    mean = tidy_report.groupby('site_id')[name].transform("mean")
    tidy_report.loc[:, new_name] = tidy_report[name] / mean
# Out:
# 0-520cm
# /tmp/ipykernel_2585139/3381475107.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tidy_report.loc[:, new_name] = tidy_report[name] / mean
# 521-660cm
# /tmp/ipykernel_2585139/3381475107.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tidy_report.loc[:, new_name] = tidy_report[name] / mean
# 661-1160cm
# /tmp/ipykernel_2585139/3381475107.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tidy_report.loc[:, new_name] = tidy_report[name] / mean
# 1160+cm
# /tmp/ipykernel_2585139/3381475107.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tidy_report.loc[:, new_name] = tidy_report[name] / mean
# total_volume
# /tmp/ipykernel_2585139/3381475107.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tidy_report.loc[:, new_name] = tidy_report[name] / mean

# %%
tidy_report
# Out:
#          site_name site_id          report_date time_period_ending  \
# 0        M42/6482L     175  2021-06-01T00:00:00           00:14:00
# 1        M42/6482L     175  2021-06-01T00:00:00           00:29:00
# 2        M42/6482L     175  2021-06-01T00:00:00           00:44:00
# 3        M42/6482L     175  2021-06-01T00:00:00           00:59:00
# 4        M42/6482L     175  2021-06-01T00:00:00           01:14:00
# ...            ...     ...                  ...                ...
# 1772040   M6/5701B   18230  2022-02-18T00:00:00           17:14:00
# 1772041   M6/5701B   18230  2022-02-18T00:00:00           17:29:00
# 1772042   M6/5701B   18230  2022-02-18T00:00:00           17:44:00
# 1772043   M6/5701B   18230  2022-02-18T00:00:00           17:59:00
# 1772044   M6/5701B   18230  2022-02-18T00:00:00           18:09:00
#
#         time_interval 0-520cm 521-660cm 661-1160cm 1160+cm avg_mph  \
# 0                   0      39         4          3       7      61
# 1                   1      37         8          2       9      65
# 2                   2      21         9          1       2      69
# 3                   3      25         4          2       6      66
# 4                   4      23         8          3       4      66
# ...               ...     ...       ...        ...     ...     ...
# 1772040            68       6         0          4       2      59
# 1772041            69       6         1          5       2      61
# 1772042            70       9         0          5       0      61
# 1772043            71      11         0          3       0      63
# 1772044            72      15         0          0       3      63
#
#         total_volume           timestamp hour DOW month 0-520cm_normalised  \
# 0                 53 2021-06-01 00:14:00    0   1     6           0.317183
# 1                 56 2021-06-01 00:29:00    0   1     6           0.300917
# 2                 33 2021-06-01 00:44:00    0   1     6           0.170791
# 3                 37 2021-06-01 00:59:00    0   1     6           0.203322
# 4                 38 2021-06-01 01:14:00    1   1     6           0.187057
# ...              ...                 ...  ...  ..   ...                ...
# 1772040           12 2022-02-18 17:14:00   17   4     2           0.020203
# 1772041           15 2022-02-18 17:29:00   17   4     2           0.020203
# 1772042           14 2022-02-18 17:44:00   17   4     2           0.030304
# 1772043           14 2022-02-18 17:59:00   17   4     2           0.037039
# 1772044           18 2022-02-18 18:09:00   18   4     2           0.050507
#
#         521-660cm_normalised 661-1160cm_normalised 1160+cm_normalised  \
# 0                   0.128501              0.210441           0.457163
# 1                   0.257003              0.140294            0.58778
# 2                   0.289128              0.070147           0.130618
# 3                   0.128501              0.140294           0.391854
# 4                   0.257003              0.210441           0.261236
# ...                      ...                   ...                ...
# 1772040                  0.0               0.15575            0.03503
# 1772041             0.046025              0.194687            0.03503
# 1772042                  0.0              0.194687                0.0
# 1772043                  0.0              0.116812                0.0
# 1772044                  0.0                   0.0           0.052546
#
#         total_volume_normalised
# 0                      0.288589
# 1                      0.304924
# 2                      0.179688
# 3                      0.201468
# 4                      0.206913
# ...                         ...
# 1772040                0.029889
# 1772041                0.037361
# 1772042                 0.03487
# 1772043                 0.03487
# 1772044                0.044833
#
# [1497715 rows x 20 columns]

# %% [markdown]
# ### Plot to check all is well

# %%
fig, ax = plt.subplots(figsize=(30,10))
tidy_report.boxplot(column='total_volume', by = 'site_id', ax=ax, grid=False, rot=45)
ax.set_title('Boxplot of vehincle counts in a 15 minute window for each site')
ax.set_ylabel('Total Volume')
plt.show()

# %%
# Check Numbers are valid
tidy_report.loc[tidy_report.total_volume == 1558]
daily_report_query_url(10398, 1, start_date='17082021', end_date='17082021')

# %%
filterd_report = tidy_report.loc[tidy_report['timestamp'].dt.to_period('M')  == '2021-08']
filterd_report.plot('timestamp','total_volume_normalised', figsize = (30,10), kind = 'scatter', alpha=0.1, c='black')
# Out:
# <AxesSubplot:xlabel='timestamp', ylabel='total_volume_normalised'>

# %%
filterd_report = tidy_report.loc[tidy_report['timestamp'].dt.to_period('M')  == '2021-08']
filterd_report.plot('timestamp','0-520cm_normalised', figsize = (30,10), kind = 'scatter', alpha=0.1, c='darkblue')
# Out:
# <AxesSubplot:xlabel='timestamp', ylabel='0-520cm_normalised'>

# %% [markdown]
# ### Export Report

# %%
tidy_report.reset_index(drop=True).to_feather('tidy_report.feather')
